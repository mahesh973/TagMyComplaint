# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from datasets import load_dataset, load_metric
from transformers import AutoTokenizer, AutoModelForSequenceClassification, TrainingArguments, Trainer, DataCollatorWithPadding
import numpy as np

# Load your dataset
data_files = {"train": "../../data_splits/train-data-split.csv", "test": "../../data_splits/test-data-split.csv"}
dataset = load_dataset("csv", data_files=data_files)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['Consumer complaint narrative', 'Product', 'Sub-product', 'Issue', 'Sub-issue'],
#         num_rows: 185637
#     })
#     test: Dataset({
#         features: ['Consumer complaint narrative', 'Product', 'Sub-product', 'Issue', 'Sub-issue'],
#         num_rows: 61880
#     })
# })

# %%
subissue_categories = np.unique(dataset['train']['Sub-issue'])
subissue_mapping = {k : i for i,k in enumerate(subissue_categories)}

def encode_categories(batch):
    return {"labels": [subissue_mapping[category] for category in batch['Sub-issue']]}
    
dataset['train'] = dataset['train'].map(encode_categories , batched=True)
dataset['test'] = dataset['test'].map(encode_categories, batched=True)
# Out:
# Map:   0%|          | 0/185637 [00:00<?, ? examples/s]
# Map:   0%|          | 0/61880 [00:00<?, ? examples/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['Consumer complaint narrative', 'Product', 'Sub-product', 'Issue', 'Sub-issue', 'labels'],
#         num_rows: 185637
#     })
#     test: Dataset({
#         features: ['Consumer complaint narrative', 'Product', 'Sub-product', 'Issue', 'Sub-issue', 'labels'],
#         num_rows: 61880
#     })
# })

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("distilbert/distilbert-base-uncased")

# %%
def preprocess_function(examples):
    return tokenizer(examples["Consumer complaint narrative"], truncation=True, padding="max_length", max_length=512)

# %%
tokenized_data = dataset.map(preprocess_function, batched=True, remove_columns=['Product', 'Sub-product','Issue', 'Sub-issue'])
# Out:
# Map:   0%|          | 0/185637 [00:00<?, ? examples/s]
# Map:   0%|          | 0/61880 [00:00<?, ? examples/s]

# %%
tokenized_data
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['Consumer complaint narrative', 'labels', 'input_ids', 'attention_mask'],
#         num_rows: 185637
#     })
#     test: Dataset({
#         features: ['Consumer complaint narrative', 'labels', 'input_ids', 'attention_mask'],
#         num_rows: 61880
#     })
# })

# %%
tokenized_data = tokenized_data.remove_columns('Consumer complaint narrative')

# %%
tokenized_data
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['labels', 'input_ids', 'attention_mask'],
#         num_rows: 185637
#     })
#     test: Dataset({
#         features: ['labels', 'input_ids', 'attention_mask'],
#         num_rows: 61880
#     })
# })

# %%
from transformers import DataCollatorWithPadding

data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

# %%
import numpy as np
import evaluate

def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    predictions = np.argmax(predictions, axis=1)
    result = {}

    metric_f1 = load_metric("f1")
    metric_precision = load_metric("precision")
    metric_recall = load_metric("recall")
    metric_acc = load_metric("accuracy")
    
    result["accuracy"] = metric_acc.compute(predictions = predictions, references = labels)["accuracy"]
    result["precision"] = metric_precision.compute(predictions = predictions, references = labels,average = 'macro')['precision']
    result["recall"] = metric_recall.compute(predictions = predictions, references = labels,average = 'macro')["recall"]
    result["f1"] = metric_f1.compute(predictions = predictions, references = labels, average = 'macro')["f1"]
    
    return result

# %%
id2label = {v : k for k,v in subissue_mapping.items()}
label2id = subissue_mapping

# %%
from transformers import AutoModelForSequenceClassification, TrainingArguments, Trainer

model = AutoModelForSequenceClassification.from_pretrained(
    "distilbert/distilbert-base-uncased", num_labels=len(id2label), id2label=id2label, label2id=label2id
)
# Out:
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert/distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
training_args = TrainingArguments(
    output_dir="distil-bert-fintuned-subissue-cfpb-complaints",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=1,
    weight_decay=0.01,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
    push_to_hub=True,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_data["train"],
    eval_dataset=tokenized_data["test"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)
# Out:
# Detected kernel version 3.10.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='11603' max='11603' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [11603/11603 40:10, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.998000</td>
#       <td>0.980947</td>
#       <td>0.710957</td>
#       <td>0.429263</td>
#       <td>0.361354</td>
#       <td>0.347383</td>
#     </tr>
#   </tbody>
# </table><p>
# /tmp/ipykernel_39946/3516474932.py:9: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   metric_f1 = load_metric("f1")
# /home/kudupudi.n/.conda/envs/pytorch_env/lib/python3.10/site-packages/datasets/load.py:753: FutureWarning: The repository for f1 contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.17.1/metrics/f1/f1.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# /home/kudupudi.n/.conda/envs/pytorch_env/lib/python3.10/site-packages/datasets/load.py:753: FutureWarning: The repository for precision contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.17.1/metrics/precision/precision.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# /home/kudupudi.n/.conda/envs/pytorch_env/lib/python3.10/site-packages/datasets/load.py:753: FutureWarning: The repository for recall contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.17.1/metrics/recall/recall.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# /home/kudupudi.n/.conda/envs/pytorch_env/lib/python3.10/site-packages/datasets/load.py:753: FutureWarning: The repository for accuracy contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.17.1/metrics/accuracy/accuracy.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# /home/kudupudi.n/.conda/envs/pytorch_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# TrainOutput(global_step=11603, training_loss=1.1837793606823297, metrics={'train_runtime': 2410.9127, 'train_samples_per_second': 76.999, 'train_steps_per_second': 4.813, 'total_flos': 2.4609269286457344e+16, 'train_loss': 1.1837793606823297, 'epoch': 1.0})

# %%
predictions = trainer.predict(tokenized_data['test'])
# Out:
# /home/kudupudi.n/.conda/envs/pytorch_env/lib/python3.10/site-packages/datasets/load.py:753: FutureWarning: The repository for f1 contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.17.1/metrics/f1/f1.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# /home/kudupudi.n/.conda/envs/pytorch_env/lib/python3.10/site-packages/datasets/load.py:753: FutureWarning: The repository for precision contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.17.1/metrics/precision/precision.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# /home/kudupudi.n/.conda/envs/pytorch_env/lib/python3.10/site-packages/datasets/load.py:753: FutureWarning: The repository for recall contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.17.1/metrics/recall/recall.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# /home/kudupudi.n/.conda/envs/pytorch_env/lib/python3.10/site-packages/datasets/load.py:753: FutureWarning: The repository for accuracy contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.17.1/metrics/accuracy/accuracy.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# /home/kudupudi.n/.conda/envs/pytorch_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
trainer.push_to_hub("Mahesh9/distil-bert-fintuned-subissue-cfpb-complaints")
# Out:
# CommitInfo(commit_url='https://huggingface.co/Mahesh9/distil-bert-fintuned-subissue-cfpb-complaints/commit/648e056574e67393e81073bd44e32aed4007e649', commit_message='Mahesh9/distil-bert-fintuned-subissue-cfpb-complaints', commit_description='', oid='648e056574e67393e81073bd44e32aed4007e649', pr_url=None, pr_revision=None, pr_num=None)

# %%
predicted_categories = np.argmax(predictions.predictions, axis=-1)
true_categories = [label2id[label] for label in dataset["test"]["Sub-issue"]]

# %%
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# Adjust the confusion matrix call to work with numeric labels
cm = confusion_matrix(true_categories, predicted_categories, labels=list(id2label.keys()))

# Convert numeric labels back to category names for visualization
product_categories = list(id2label.values())

fig, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', ax=ax, cmap='Blues', xticklabels=product_categories, yticklabels=product_categories)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %%
report = classification_report(true_categories, predicted_categories, target_names=product_categories)
print(report)
# Out:
#                                                                                        precision    recall  f1-score   support
#
#                                                         Account information incorrect       0.40      0.33      0.36      2281
#                                                   Account opened as a result of fraud       0.58      0.69      0.63       135
#                                                              Account status incorrect       0.56      0.52      0.54      2502
#                                                     Attempted to collect wrong amount       0.00      0.00      0.00       202
#                                                                        Banking errors       0.53      0.03      0.07       231
#                                                                       Billing problem       0.33      0.01      0.02       126
#                                                              Can't close your account       0.00      0.00      0.00       165
#                                      Card opened as result of identity theft or fraud       0.31      0.07      0.12       120
#                     Card was charged for something you did not purchase with the card       0.34      0.05      0.08       265
#                                                           Company closed your account       0.36      0.64      0.46       374
#      Credit card company isn't resolving a dispute about a purchase on your statement       0.46      0.81      0.58       576
#                              Credit inquiries on your report that you don't recognize       0.70      0.76      0.73      3242
#                                                                     Debt is not yours       0.33      0.56      0.41       721
#                                                                         Debt was paid       0.30      0.35      0.33       221
#                                                     Debt was result of identity theft       0.51      0.19      0.28       439
#                                                              Deposits and withdrawals       0.37      0.71      0.48       620
#                                      Didn't receive enough information to verify debt       0.70      0.35      0.47       429
#                                             Didn't receive notice of right to dispute       0.00      0.00      0.00       149
# Difficulty submitting a dispute or getting information about a dispute over the phone       0.46      0.15      0.23       435
#                                                                           Fee problem       0.45      0.09      0.15       208
#                                          Funds not handled or disbursed as instructed       0.00      0.00      0.00       232
#                                                Funds not received from closed account       0.00      0.00      0.00       173
#                                                   Information belongs to someone else       0.81      0.86      0.84     14486
#                                   Information is missing that should be on the report       0.00      0.00      0.00       225
#                                                  Investigation took more than 30 days       0.80      0.68      0.74      2222
#                                          Old information reappears or never goes away       0.46      0.11      0.17       454
#                                                                         Other problem       0.50      0.07      0.13       162
#                                     Other problem getting your report or credit score       0.52      0.57      0.54       290
#                                                         Overdrafts and overdraft fees       0.34      0.72      0.46       215
#                                                        Personal information incorrect       0.76      0.79      0.77      1497
#                                                             Problem accessing account       0.44      0.04      0.08       159
#              Problem canceling credit monitoring or identify theft protection service       1.00      0.26      0.42       122
#                                                        Problem during payment process       0.36      0.63      0.46       189
#                                                     Problem using a debit or ATM card       0.34      0.49      0.41       376
#                                                                     Problem with fees       0.54      0.53      0.53       186
#                                            Problem with personal statement of dispute       0.00      0.00      0.00       340
#                                                  Public record information inaccurate       0.43      0.33      0.37       362
#                                              Received bad information about your loan       0.57      0.87      0.69       180
#                                         Reporting company used your report improperly       0.78      0.84      0.81     12192
#                               Their investigation did not fix an error on your report       0.73      0.79      0.76     11333
#                                  Threatened or suggested your credit would be damaged       0.00      0.00      0.00       184
#                                                        Transaction was not authorized       0.25      0.07      0.11       364
#                                           Trouble with how payments are being handled       0.66      0.14      0.23       134
#                                   Was not notified of investigation status or results       0.89      0.78      0.83      2362
#
#                                                                              accuracy                           0.71     61880
#                                                                             macro avg       0.43      0.36      0.35     61880
#                                                                          weighted avg       0.69      0.71      0.69     61880
# /home/kudupudi.n/.conda/envs/pytorch_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/kudupudi.n/.conda/envs/pytorch_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/kudupudi.n/.conda/envs/pytorch_env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import pandas as pd

true_labels_text = [id2label[label] for label in true_categories]
predicted_labels_text = [id2label[label] for label in predicted_categories]

results_df = pd.DataFrame({
    'True Labels': true_labels_text,
    'Predicted Labels': predicted_labels_text
})

original_texts = [tokenizer.decode(ids, skip_special_tokens=True) for ids in tokenized_data["test"]["input_ids"]]
results_df['Complaint Narrative'] = original_texts

# %%
results_df.to_csv('distil-bert-fintuned-subissue-cfpb-complaints/saved_results/model_predictions_and_labels.csv', index=False)
